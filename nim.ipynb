# %% [markdown]
# # Nim
#
# Decided to dump code here to show execution.

# %%
import random
import math
import time

# %%
epochs = 700
EPSILON = 0.15 # probability AI makes a random move the next round
ALPHA = 0.5 # learning rate
GAME_BOARD = [5,7,9] # index represents a pile and value at each index represents content

# %% [markdown]
# ## The board

# %%
class Nim():

  def __init__(self, initial=GAME_BOARD):
      """
      Initialize game board.
      Each game board has
          - `piles`: a list of how many elements remain in each pile
          - `player`: 0 or 1 to indicate which player's turn
          - `winner`: None, 0, or 1 to indicate who the winner is
      """
      self.piles = initial.copy()
      self.player = 0
      self.winner = None

  @classmethod
  def available_actions(cls, piles):
      """
      Nim.available_actions(piles) takes a `piles` list as input
      and returns all of the available actions `(i, j)` in that state.

      Action `(i, j)` represents the action of removing `j` items
      from pile `i` (where piles are 0-indexed).
      """
      actions = set()
      for i, pile in enumerate(piles):
          for j in range(1, pile + 1):
              actions.add((i, j))
      return actions

  @classmethod
  def other_player(cls, player):
      """
      Nim.other_player(player) returns the player that is not
      `player`. Assumes `player` is either 0 or 1.
      """
      return 0 if player == 1 else 1

  def switch_player(self):
      """
      Switch the current player to the other player.
      """
      self.player = Nim.other_player(self.player)

  def move(self, action):
      """
      Make the move `action` for the current player.
      `action` must be a tuple `(i, j)`.
      """
      pile, count = action

      # Check for errors
      if self.winner is not None:
          raise Exception("Game already won")
      elif pile < 0 or pile >= len(self.piles):
          raise Exception("Invalid pile")
      elif count < 1 or count > self.piles[pile]:
          raise Exception("Invalid number of objects")

      # Update pile
      self.piles[pile] -= count
      self.switch_player()

      # Check for a winner
      if all(pile == 0 for pile in self.piles):
          self.winner = self.player

# %% [markdown]
# ## The AI to play against

# %%
class NimAI():

  def __init__(self, alpha=ALPHA, epsilon=EPSILON):
      """
      Initialize AI with an empty Q-learning dictionary,
      an alpha (learning) rate, and an epsilon rate.

      The Q-learning dictionary maps `(state, action)`
      pairs to a Q-value (a number).
        - `state` is a tuple of remaining piles, e.g. (1, 1, 4, 4)
        - `action` is a tuple `(i, j)` for an action
      """
      self.q = dict()
      self.alpha = alpha
      self.epsilon = epsilon

  def update(self, old_state, action, new_state, reward):
      """
      Update Q-learning model, given an old state, an action taken
      in that state, a new resulting state, and the reward received
      from taking that action.
      """
      old = self.get_q_value(old_state, action)
      best_future = self.best_future_reward(new_state)
      self.update_q_value(old_state, action, old, reward, best_future)

  def get_q_value(self, state, action):
      """
      Return the Q-value for the state `state` and the action `action`.
      If no Q-value exists yet in `self.q`, return 0.
      """
      if (tuple(state), action) not in self.q:
          return 0

      return self.q[tuple(state), action]

  def update_q_value(self, state, action, old_q, reward, future_rewards):
      """
      Update the Q-value for the state `state` and the action `action`
      given the previous Q-value `old_q`, a current reward `reward`,
      and an estiamte of future rewards `future_rewards`.
      Use the formula:
      Q(s, a) <- old value estimate
                  + alpha * (new value estimate - old value estimate)
      where `old value estimate` is the previous Q-value,
      `alpha` is the learning rate, and `new value estimate`
      is the sum of the current reward and estimated future rewards.
      """
      self.q[tuple(state), action] = old_q + self.alpha * (reward + future_rewards - old_q)

  def best_future_reward(self, state):
      """
      Given a state `state`, consider all possible `(state, action)`
      pairs available in that state and return the maximum of all
      of their Q-values.
      Use 0 as the Q-value if a `(state, action)` pair has no
      Q-value in `self.q`. If there are no available actions in
      `state`, return 0.
      """
      best_reward = 0

      for available_action in Nim.available_actions(state):
          if self.get_q_value(state, available_action) > best_reward:
              best_reward = self.get_q_value(state, available_action)

      return best_reward

  def choose_action(self, state, epsilon=True):
      """
      Given a state `state`, return an action `(i, j)` to take.
      If `epsilon` is `False`, then return the best action
      available in the state (the one with the highest Q-value,
      using 0 for pairs that have no Q-values).
      If `epsilon` is `True`, then with probability
      `self.epsilon` choose a random available action,
      otherwise choose the best action available.
      If multiple actions have the same Q-value, any of those
      options is an acceptable return value.
      """
      available_actions = Nim.available_actions(state)

      # Choose random available action
      if epsilon and random.random() <= self.epsilon:
          return random.sample(list(available_actions), 1)[0]

      # Otherwise choose best available action
      best_reward = -math.inf

      for available_action in available_actions:
          if self.get_q_value(state, available_action) > best_reward:
              best_reward = self.get_q_value(state, available_action)
              best_action = available_action

      return best_action

# %% [markdown]
# ## Training the AI

# %%
def train(n):
  """
  Train an AI by playing `n` games against itself.
  """

  player = NimAI()

  # Play n games
  for i in range(n):
      print(f"Playing training game {i + 1}")
      game = Nim()

      # Keep track of last move made by either player
      last = {
          0: {"state": None, "action": None},
          1: {"state": None, "action": None}
      }

      # Game loop
      while True:

          # Keep track of current state and action
          state = game.piles.copy()
          action = player.choose_action(game.piles)

          # Keep track of last state and action
          last[game.player]["state"] = state
          last[game.player]["action"] = action

          # Make move
          game.move(action)
          new_state = game.piles.copy()

          # When game is over, update Q values with rewards
          if game.winner is not None:
              player.update(state, action, new_state, -1)
              player.update(
                  last[game.player]["state"],
                  last[game.player]["action"],
                  new_state,
                  1
              )
              break

          # If game is continuing, no rewards yet
          elif last[game.player]["state"] is not None:
              player.update(
                  last[game.player]["state"],
                  last[game.player]["action"],
                  new_state,
                  0
              )

  print("Done training")

  # Return the trained AI
  return player

# %% [markdown]
# ## Execution logic

# %%
def play(ai, human_player=None):
  """
  Play human game against the AI.
  `human_player` can be set to 0 or 1 to specify whether
  human player moves first or second.
  """

  # If no player order set, choose human's order randomly
  if human_player is None:
      human_player = random.randint(0, 1)

  # Create new game
  game = Nim()

  # Game loop
  while True:

      # Print contents of piles
      print()
      print("Piles:")
      for i, pile in enumerate(game.piles):
          print(f"Pile {i}: {pile}")
      print()

      # Compute available actions
      available_actions = Nim.available_actions(game.piles)
      time.sleep(1)

      # Let human make a move
      if game.player == human_player:
          print("Your Turn")
          while True:
              pile = int(input("Choose a pile: "))
              count = int(input("Choose how many to remove: "))
              if (pile, count) in available_actions:
                  break
              print("Invalid move, try again.")

      # Have AI make a move
      else:
          print("AI's Turn")
          pile, count = ai.choose_action(game.piles, epsilon=False)
          print(f"AI chose to take {count} from pile {pile}.")

      # Make move
      game.move((pile, count))

      # Check for winner
      if game.winner is not None:
          print()
          print("GAME OVER")
          winner = "Human" if game.winner == human_player else "AI"
          print(f"Winner is {winner}")
          return

# %% [markdown]
# ## **Execute!**

# %%
start_time = time.time()
ai = train(epochs)
print(f"Train time: {time.time() - start_time}")
# Out:
# Playing training game 1
# Playing training game 2
# Playing training game 3
# Playing training game 4
# Playing training game 5
# Playing training game 6
# Playing training game 7
# Playing training game 8
# Playing training game 9
# Playing training game 10
# Playing training game 11
# Playing training game 12
# Playing training game 13
# Playing training game 14
# Playing training game 15
# Playing training game 16
# Playing training game 17
# Playing training game 18
# Playing training game 19
# Playing training game 20
# Playing training game 21
# Playing training game 22
# Playing training game 23
# Playing training game 24
# Playing training game 25
# Playing training game 26
# Playing training game 27
# Playing training game 28
# Playing training game 29
# Playing training game 30
# Playing training game 31
# Playing training game 32
# Playing training game 33
# Playing training game 34
# Playing training game 35
# Playing training game 36
# Playing training game 37
# Playing training game 38
# Playing training game 39
# Playing training game 40
# Playing training game 41
# Playing training game 42
# Playing training game 43
# Playing training game 44
# Playing training game 45
# Playing training game 46
# Playing training game 47
# Playing training game 48
# Playing training game 49
# Playing training game 50
# Playing training game 51
# Playing training game 52
# Playing training game 53
# Playing training game 54
# Playing training game 55
# Playing training game 56
# Playing training game 57
# Playing training game 58
# Playing training game 59
# Playing training game 60
# Playing training game 61
# Playing training game 62
# Playing training game 63
# Playing training game 64
# Playing training game 65
# Playing training game 66
# Playing training game 67
# Playing training game 68
# Playing training game 69
# Playing training game 70
# Playing training game 71
# Playing training game 72
# Playing training game 73
# Playing training game 74
# Playing training game 75
# Playing training game 76
# Playing training game 77
# Playing training game 78
# Playing training game 79
# Playing training game 80
# Playing training game 81
# Playing training game 82
# Playing training game 83
# Playing training game 84
# Playing training game 85
# Playing training game 86
# Playing training game 87
# Playing training game 88
# Playing training game 89
# Playing training game 90
# Playing training game 91
# Playing training game 92
# Playing training game 93
# Playing training game 94
# Playing training game 95
# Playing training game 96
# Playing training game 97
# Playing training game 98
# Playing training game 99
# Playing training game 100
# Playing training game 101
# Playing training game 102
# Playing training game 103
# Playing training game 104
# Playing training game 105
# Playing training game 106
# Playing training game 107
# Playing training game 108
# Playing training game 109
# Playing training game 110
# Playing training game 111
# Playing training game 112
# Playing training game 113
# Playing training game 114
# Playing training game 115
# Playing training game 116
# Playing training game 117
# Playing training game 118
# Playing training game 119
# Playing training game 120
# Playing training game 121
# Playing training game 122
# Playing training game 123
# Playing training game 124
# Playing training game 125
# Playing training game 126
# Playing training game 127
# Playing training game 128
# Playing training game 129
# Playing training game 130
# Playing training game 131
# Playing training game 132
# Playing training game 133
# Playing training game 134
# Playing training game 135
# Playing training game 136
# Playing training game 137
# Playing training game 138
# Playing training game 139
# Playing training game 140
# Playing training game 141
# Playing training game 142
# Playing training game 143
# Playing training game 144
# Playing training game 145
# Playing training game 146
# Playing training game 147
# Playing training game 148
# Playing training game 149
# Playing training game 150
# Playing training game 151
# Playing training game 152
# Playing training game 153
# Playing training game 154
# Playing training game 155
# Playing training game 156
# Playing training game 157
# Playing training game 158
# Playing training game 159
# Playing training game 160
# Playing training game 161
# Playing training game 162
# Playing training game 163
# Playing training game 164
# Playing training game 165
# Playing training game 166
# Playing training game 167
# Playing training game 168
# Playing training game 169
# Playing training game 170
# Playing training game 171
# Playing training game 172
# Playing training game 173
# Playing training game 174
# Playing training game 175
# Playing training game 176
# Playing training game 177
# Playing training game 178
# Playing training game 179
# Playing training game 180
# Playing training game 181
# Playing training game 182
# Playing training game 183
# Playing training game 184
# Playing training game 185
# Playing training game 186
# Playing training game 187
# Playing training game 188
# Playing training game 189
# Playing training game 190
# Playing training game 191
# Playing training game 192
# Playing training game 193
# Playing training game 194
# Playing training game 195
# Playing training game 196
# Playing training game 197
# Playing training game 198
# Playing training game 199
# Playing training game 200
# Playing training game 201
# Playing training game 202
# Playing training game 203
# Playing training game 204
# Playing training game 205
# Playing training game 206
# Playing training game 207
# Playing training game 208
# Playing training game 209
# Playing training game 210
# Playing training game 211
# Playing training game 212
# Playing training game 213
# Playing training game 214
# Playing training game 215
# Playing training game 216
# Playing training game 217
# Playing training game 218
# Playing training game 219
# Playing training game 220
# Playing training game 221
# Playing training game 222
# Playing training game 223
# Playing training game 224
# Playing training game 225
# Playing training game 226
# Playing training game 227
# Playing training game 228
# Playing training game 229
# Playing training game 230
# Playing training game 231
# Playing training game 232
# Playing training game 233
# Playing training game 234
# Playing training game 235
# Playing training game 236
# Playing training game 237
# Playing training game 238
# Playing training game 239
# Playing training game 240
# Playing training game 241
# Playing training game 242
# Playing training game 243
# Playing training game 244
# Playing training game 245
# Playing training game 246
# Playing training game 247
# Playing training game 248
# Playing training game 249
# Playing training game 250
# Playing training game 251
# Playing training game 252
# Playing training game 253
# Playing training game 254
# Playing training game 255
# Playing training game 256
# Playing training game 257
# Playing training game 258
# Playing training game 259
# Playing training game 260
# Playing training game 261
# Playing training game 262
# Playing training game 263
# Playing training game 264
# Playing training game 265
# Playing training game 266
# Playing training game 267
# Playing training game 268
# Playing training game 269
# Playing training game 270
# Playing training game 271
# Playing training game 272
# Playing training game 273
# Playing training game 274
# Playing training game 275
# Playing training game 276
# Playing training game 277
# Playing training game 278
# Playing training game 279
# Playing training game 280
# Playing training game 281
# Playing training game 282
# Playing training game 283
# Playing training game 284
# Playing training game 285
# Playing training game 286
# Playing training game 287
# Playing training game 288
# Playing training game 289
# Playing training game 290
# Playing training game 291
# Playing training game 292
# Playing training game 293
# Playing training game 294
# Playing training game 295
# Playing training game 296
# Playing training game 297
# Playing training game 298
# Playing training game 299
# Playing training game 300
# Playing training game 301
# Playing training game 302
# Playing training game 303
# Playing training game 304
# Playing training game 305
# Playing training game 306
# Playing training game 307
# Playing training game 308
# Playing training game 309
# Playing training game 310
# Playing training game 311
# Playing training game 312
# Playing training game 313
# Playing training game 314
# Playing training game 315
# Playing training game 316
# Playing training game 317
# Playing training game 318
# Playing training game 319
# Playing training game 320
# Playing training game 321
# Playing training game 322
# Playing training game 323
# Playing training game 324
# Playing training game 325
# Playing training game 326
# Playing training game 327
# Playing training game 328
# Playing training game 329
# Playing training game 330
# Playing training game 331
# Playing training game 332
# Playing training game 333
# Playing training game 334
# Playing training game 335
# Playing training game 336
# Playing training game 337
# Playing training game 338
# Playing training game 339
# Playing training game 340
# Playing training game 341
# Playing training game 342
# Playing training game 343
# Playing training game 344
# Playing training game 345
# Playing training game 346
# Playing training game 347
# Playing training game 348
# Playing training game 349
# Playing training game 350
# Playing training game 351
# Playing training game 352
# Playing training game 353
# Playing training game 354
# Playing training game 355
# Playing training game 356
# Playing training game 357
# Playing training game 358
# Playing training game 359
# Playing training game 360
# Playing training game 361
# Playing training game 362
# Playing training game 363
# Playing training game 364
# Playing training game 365
# Playing training game 366
# Playing training game 367
# Playing training game 368
# Playing training game 369
# Playing training game 370
# Playing training game 371
# Playing training game 372
# Playing training game 373
# Playing training game 374
# Playing training game 375
# Playing training game 376
# Playing training game 377
# Playing training game 378
# Playing training game 379
# Playing training game 380
# Playing training game 381
# Playing training game 382
# Playing training game 383
# Playing training game 384
# Playing training game 385
# Playing training game 386
# Playing training game 387
# Playing training game 388
# Playing training game 389
# Playing training game 390
# Playing training game 391
# Playing training game 392
# Playing training game 393
# Playing training game 394
# Playing training game 395
# Playing training game 396
# Playing training game 397
# Playing training game 398
# Playing training game 399
# Playing training game 400
# Playing training game 401
# Playing training game 402
# Playing training game 403
# Playing training game 404
# Playing training game 405
# Playing training game 406
# Playing training game 407
# Playing training game 408
# Playing training game 409
# Playing training game 410
# Playing training game 411
# Playing training game 412
# Playing training game 413
# Playing training game 414
# Playing training game 415
# Playing training game 416
# Playing training game 417
# Playing training game 418
# Playing training game 419
# Playing training game 420
# Playing training game 421
# Playing training game 422
# Playing training game 423
# Playing training game 424
# Playing training game 425
# Playing training game 426
# Playing training game 427
# Playing training game 428
# Playing training game 429
# Playing training game 430
# Playing training game 431
# Playing training game 432
# Playing training game 433
# Playing training game 434
# Playing training game 435
# Playing training game 436
# Playing training game 437
# Playing training game 438
# Playing training game 439
# Playing training game 440
# Playing training game 441
# Playing training game 442
# Playing training game 443
# Playing training game 444
# Playing training game 445
# Playing training game 446
# Playing training game 447
# Playing training game 448
# Playing training game 449
# Playing training game 450
# Playing training game 451
# Playing training game 452
# Playing training game 453
# Playing training game 454
# Playing training game 455
# Playing training game 456
# Playing training game 457
# Playing training game 458
# Playing training game 459
# Playing training game 460
# Playing training game 461
# Playing training game 462
# Playing training game 463
# Playing training game 464
# Playing training game 465
# Playing training game 466
# Playing training game 467
# Playing training game 468
# Playing training game 469
# Playing training game 470
# Playing training game 471
# Playing training game 472
# Playing training game 473
# Playing training game 474
# Playing training game 475
# Playing training game 476
# Playing training game 477
# Playing training game 478
# Playing training game 479
# Playing training game 480
# Playing training game 481
# Playing training game 482
# Playing training game 483
# Playing training game 484
# Playing training game 485
# Playing training game 486
# Playing training game 487
# Playing training game 488
# Playing training game 489
# Playing training game 490
# Playing training game 491
# Playing training game 492
# Playing training game 493
# Playing training game 494
# Playing training game 495
# Playing training game 496
# Playing training game 497
# Playing training game 498
# Playing training game 499
# Playing training game 500
# Playing training game 501
# Playing training game 502
# Playing training game 503
# Playing training game 504
# Playing training game 505
# Playing training game 506
# Playing training game 507
# Playing training game 508
# Playing training game 509
# Playing training game 510
# Playing training game 511
# Playing training game 512
# Playing training game 513
# Playing training game 514
# Playing training game 515
# Playing training game 516
# Playing training game 517
# Playing training game 518
# Playing training game 519
# Playing training game 520
# Playing training game 521
# Playing training game 522
# Playing training game 523
# Playing training game 524
# Playing training game 525
# Playing training game 526
# Playing training game 527
# Playing training game 528
# Playing training game 529
# Playing training game 530
# Playing training game 531
# Playing training game 532
# Playing training game 533
# Playing training game 534
# Playing training game 535
# Playing training game 536
# Playing training game 537
# Playing training game 538
# Playing training game 539
# Playing training game 540
# Playing training game 541
# Playing training game 542
# Playing training game 543
# Playing training game 544
# Playing training game 545
# Playing training game 546
# Playing training game 547
# Playing training game 548
# Playing training game 549
# Playing training game 550
# Playing training game 551
# Playing training game 552
# Playing training game 553
# Playing training game 554
# Playing training game 555
# Playing training game 556
# Playing training game 557
# Playing training game 558
# Playing training game 559
# Playing training game 560
# Playing training game 561
# Playing training game 562
# Playing training game 563
# Playing training game 564
# Playing training game 565
# Playing training game 566
# Playing training game 567
# Playing training game 568
# Playing training game 569
# Playing training game 570
# Playing training game 571
# Playing training game 572
# Playing training game 573
# Playing training game 574
# Playing training game 575
# Playing training game 576
# Playing training game 577
# Playing training game 578
# Playing training game 579
# Playing training game 580
# Playing training game 581
# Playing training game 582
# Playing training game 583
# Playing training game 584
# Playing training game 585
# Playing training game 586
# Playing training game 587
# Playing training game 588
# Playing training game 589
# Playing training game 590
# Playing training game 591
# Playing training game 592
# Playing training game 593
# Playing training game 594
# Playing training game 595
# Playing training game 596
# Playing training game 597
# Playing training game 598
# Playing training game 599
# Playing training game 600
# Playing training game 601
# Playing training game 602
# Playing training game 603
# Playing training game 604
# Playing training game 605
# Playing training game 606
# Playing training game 607
# Playing training game 608
# Playing training game 609
# Playing training game 610
# Playing training game 611
# Playing training game 612
# Playing training game 613
# Playing training game 614
# Playing training game 615
# Playing training game 616
# Playing training game 617
# Playing training game 618
# Playing training game 619
# Playing training game 620
# Playing training game 621
# Playing training game 622
# Playing training game 623
# Playing training game 624
# Playing training game 625
# Playing training game 626
# Playing training game 627
# Playing training game 628
# Playing training game 629
# Playing training game 630
# Playing training game 631
# Playing training game 632
# Playing training game 633
# Playing training game 634
# Playing training game 635
# Playing training game 636
# Playing training game 637
# Playing training game 638
# Playing training game 639
# Playing training game 640
# Playing training game 641
# Playing training game 642
# Playing training game 643
# Playing training game 644
# Playing training game 645
# Playing training game 646
# Playing training game 647
# Playing training game 648
# Playing training game 649
# Playing training game 650
# Playing training game 651
# Playing training game 652
# Playing training game 653
# Playing training game 654
# Playing training game 655
# Playing training game 656
# Playing training game 657
# Playing training game 658
# Playing training game 659
# Playing training game 660
# Playing training game 661
# Playing training game 662
# Playing training game 663
# Playing training game 664
# Playing training game 665
# Playing training game 666
# Playing training game 667
# Playing training game 668
# Playing training game 669
# Playing training game 670
# Playing training game 671
# Playing training game 672
# Playing training game 673
# Playing training game 674
# Playing training game 675
# Playing training game 676
# Playing training game 677
# Playing training game 678
# Playing training game 679
# Playing training game 680
# Playing training game 681
# Playing training game 682
# Playing training game 683
# Playing training game 684
# Playing training game 685
# Playing training game 686
# Playing training game 687
# Playing training game 688
# Playing training game 689
# Playing training game 690
# Playing training game 691
# Playing training game 692
# Playing training game 693
# Playing training game 694
# Playing training game 695
# Playing training game 696
# Playing training game 697
# Playing training game 698
# Playing training game 699
# Playing training game 700
# Done training
# Train time: 0.3680868148803711

# %%
play(ai)
# Out:
# Piles:
# Pile 0: 5
# Pile 1: 7
# Pile 2: 9
#
# AI's Turn
# AI chose to take 2 from pile 0.
#
# Piles:
# Pile 0: 3
# Pile 1: 7
# Pile 2: 9
#
# Your Turn
# Choose a pile: 1
# Choose how many to remove: 5
#
# Piles:
# Pile 0: 3
# Pile 1: 2
# Pile 2: 9
#
# AI's Turn
# AI chose to take 1 from pile 2.
#
# Piles:
# Pile 0: 3
# Pile 1: 2
# Pile 2: 8
#
# Your Turn
# Choose a pile: 2
# Choose how many to remove: 6
#
# Piles:
# Pile 0: 3
# Pile 1: 2
# Pile 2: 2
#
# AI's Turn
# AI chose to take 1 from pile 1.
#
# Piles:
# Pile 0: 3
# Pile 1: 1
# Pile 2: 2
#
# Your Turn
# Choose a pile: 1
# Choose how many to remove: 3
# Invalid move, try again.
# Choose a pile: 0
# Choose how many to remove: 3
#
# Piles:
# Pile 0: 0
# Pile 1: 1
# Pile 2: 2
#
# AI's Turn
# AI chose to take 2 from pile 2.
#
# Piles:
# Pile 0: 0
# Pile 1: 1
# Pile 2: 0
#
# Your Turn
# Choose a pile: 1
# Choose how many to remove: 1
#
# GAME OVER
# Winner is AI
